# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#PROJECT-TITLE:-Development-&amp;-Deployment-of-SQL-Database-Focused-Online-Book-Catalog-Application" data-toc-modified-id="PROJECT-TITLE:-Development-&amp;-Deployment-of-SQL-Database-Focused-Online-Book-Catalog-Application-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>PROJECT TITLE: Development &amp; Deployment of SQL-Database Focused Online Book Catalog Application</a></span><ul class="toc-item"><li><span><a href="#Project-Outline" data-toc-modified-id="Project-Outline-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Project Outline</a></span></li><li><span><a href="#Project-Execution-Steps-for-Both-Phases" data-toc-modified-id="Project-Execution-Steps-for-Both-Phases-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Project Execution Steps for Both Phases</a></span></li></ul></li><li><span><a href="#Phase-1:-Development-of-Book-Catalog-Using-PostgreSQL,-SQLAlchemy,-PyCharm-&amp;-Flask-and-Run-in-the-Local-Desktop-Environment" data-toc-modified-id="Phase-1:-Development-of-Book-Catalog-Using-PostgreSQL,-SQLAlchemy,-PyCharm-&amp;-Flask-and-Run-in-the-Local-Desktop-Environment-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Phase-1: Development of Book Catalog Using PostgreSQL, SQLAlchemy, PyCharm &amp; Flask and Run in the Local Desktop Environment</a></span><ul class="toc-item"><li><span><a href="#Project-Goals" data-toc-modified-id="Project-Goals-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Project Goals</a></span></li><li><span><a href="#Project-Execution-Steps-for-Phase-1" data-toc-modified-id="Project-Execution-Steps-for-Phase-1-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Project Execution Steps for Phase-1</a></span><ul class="toc-item"><li><span><a href="#Development-of-Virtual-Environment" data-toc-modified-id="Development-of-Virtual-Environment-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Development of Virtual Environment</a></span></li></ul></li><li><span><a href="#Development-of-File-Structure" data-toc-modified-id="Development-of-File-Structure-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Development of File Structure</a></span></li><li><span><a href="#Database-Development-Using-PostgreSQL-and-SQLAlchemy" data-toc-modified-id="Database-Development-Using-PostgreSQL-and-SQLAlchemy-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Database Development Using PostgreSQL and SQLAlchemy</a></span></li><li><span><a href="#Using-Bootstrap-for-Better-Application-User-Interface-(UI)-Experience" data-toc-modified-id="Using-Bootstrap-for-Better-Application-User-Interface-(UI)-Experience-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Using Bootstrap for Better Application User Interface (UI) Experience</a></span></li><li><span><a href="#Running-of-Books-Catalog-App-from-the-Local-Server-in-the-Browser" data-toc-modified-id="Running-of-Books-Catalog-App-from-the-Local-Server-in-the-Browser-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Running of Books Catalog App from the Local Server in the Browser</a></span></li><li><span><a href="#Video-Walk-through-of-the-Phase-1-Project" data-toc-modified-id="Video-Walk-through-of-the-Phase-1-Project-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Video Walk-through of the Phase-1 Project</a></span></li></ul></li><li><span><a href="#Phase-2:-Deployment-of-Book-Catalog-Using-GitHub,-Amazon-S3-&amp;-Heroku-(To-be-done-later)" data-toc-modified-id="Phase-2:-Deployment-of-Book-Catalog-Using-GitHub,-Amazon-S3-&amp;-Heroku-(To-be-done-later)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Phase-2: Deployment of Book Catalog Using GitHub, Amazon S3 &amp; Heroku (To be done later)</a></span><ul class="toc-item"><li><span><a href="#Project-Goals" data-toc-modified-id="Project-Goals-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Project Goals</a></span></li><li><span><a href="#Project-Execution-Steps-for-Phase-2" data-toc-modified-id="Project-Execution-Steps-for-Phase-2-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Project Execution Steps for Phase-2</a></span><ul class="toc-item"><li><span><a href="#Deployment-to-Heroku-via-GitHub" data-toc-modified-id="Deployment-to-Heroku-via-GitHub-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Deployment to Heroku via GitHub</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # PROJECT TITLE: Development & Deployment of SQL-Database Focused Online Book Catalog Application

# %% [markdown]
# ## Project Outline

# %% [markdown]
# Since the project is focused on the development of database, the project will be done in 2 phases to keep the focus on the step-by-step execution and documentation:
#
# **Phase-1: Focus on the development of the database and app for the local desktop environment**
#
#     1. Create a database in the PostgreSQL in the desktop environment
#     2. Create required tables and populate tables with required information
#     3. Create User Interface and run the app in the local desktop environment by accessing content from the PostgreSQL local server and generating pages based on the database information
#
# **Phase-2: Focus on the deployment of the database and app for the online environment**
#
#     1. While all the features of the app will be developed in the first phase, user login features will be developed in the second phase
#     2. Upload all the coding files in the GitHub repository
#     3. Create a cloud storage like Amazon S3 to store the database information for online access
#     4. Create Heroku application using their hobby plan

# %% [markdown]
# ## Project Execution Steps for Both Phases

# %% [markdown]
# ![bookcatalog_steps.jpg](attachment:bookcatalog_steps.jpg)

# %% [markdown]
# # Phase-1: Development of Book Catalog Using PostgreSQL, SQLAlchemy, PyCharm & Flask and Run in the Local Desktop Environment

# %% [markdown]
# ## Project Goals

# %% [markdown]
# *Phase-1: Development of a Book Catalog fully active in the local desktop or laptop environment using the following resources:*
#
# - **PostgreSQL to develop Book Catalog**
# - **Use of SQLAlchemy along with Psycopg2**
# - *Use of Flask and Jinja2 templates and macros to develop user interface (UI)*
# - *Use of PyCharm IDE and terminal to achieve various tasks*

# %% [markdown]
# ## Project Execution Steps for Phase-1

# %% [markdown]
# ![bookcatalog_step1to3.jpg](attachment:bookcatalog_step1to3.jpg)

# %% [markdown]
# ### Development of Virtual Environment

# %% [markdown]
# Following commands were executed using terminal interface for the selected folder location:
#
# - pip install virtualenv
# - mkdir flaskproject
# - cd flaskproject
# - virtualenv flaskenv
# - flaskenv\scripts\activate
# - pip install flask
# - pip install Jinja2
# - pip install flask-bootstrap
# - pip install SQLAlchemy
# - pip install psycopg2
# - pip install gunicorn
#
# While selecting the virtual environment, I have kept the phase-2 in mind. Hence all the packages are included here.

# %% [markdown]
# **REFERENCES FOR ABOVE PACKAGE INSTALLATIONS**
# - Psycopg2 at https://pypi.org/project/psycopg2/
# - SQLAlchemy at https://pypi.org/project/SQLAlchemy/
# - Flask at https://pypi.org/project/Flask/
# - Jinja2 at https://pypi.org/project/Jinja2/
# - Bootstrap at https://getbootstrap.com/
# - Gunicorn at https://docs.gunicorn.org/en/stable/install.html

# %% [markdown]
# ## Development of File Structure

# %% [markdown]
# Using **PyCharm** IDE, following files were created:

# %% [markdown]
# ![fileorg.png](attachment:fileorg.png)

# %% [markdown]
# Keeping files separate for each different function will ensure better scalability in future. During the phase 2, user login interface as well as the system required will be created.

# %% [markdown]
# ## Database Development Using PostgreSQL and SQLAlchemy

# %% [markdown]
# Started the files as mentioned above to focus on one file for one functionality and using PyCharm environment to build the Database table and populate that table from there.
#
# **table-1: Publication**
#
# **table-2: Books**
#
# I created a new database in the pgAdmin with the name as **catalog_db** and tables will be created using the PyCharm terminal now.
#
# Table Name: **Publication**
# - **pub_id (primary key)**
# - **pub_name**
#
# Table Name: **Books**
# - **book_id (primary key)**
# - **book_title**
# - **author**
# - **rating**
# - **format**
# - **image_url**
# - **num_pages**
# - **pub_date**
# - **pub_id (foreign key)**

# %% [markdown]
# Here is the code used in the models.py file which is meant for the db development:
#
# **PUBLICATION TABLE**
#
# class Publication(db.Model):
#     __tablename__ = 'publication'
#
#     id = db.Column(db.Integer, primary_key=True)
#     name = db.Column(db.String(80), nullable=False)
#
#     def __init__(self, name):
#         self.name = name
#
#     def __repr__(self):
#         return 'The Publisher is {}'.format(self.name)
#
# **BOOKS TABLE**
#
# class Book(db.Model):
#     __tablename__ = 'book'
#
#     id = db.Column(db.Integer, primary_key=True)
#     title = db.Column(db.String(500), nullable=False, index=True)
#     author = db.Column(db.String(350))
#     avg_rating = db.Column(db.Float)
#     format = db.Column(db.String(50))
#     image = db.Column(db.String(100), unique=True)
#     num_pages = db.Column(db.Integer)
#     pub_date = db.Column(db.DateTime, default=datetime.utcnow())
#
# ** ESTABLISH RELATIONSHIP**
#
#     pub_id = db.Column(db.Integer, db.ForeignKey('publication.id'))
#
#     def __init__(self, title, author, avg_rating, book_format, image, num_pages, pub_id):
#         self.title = title
#         self.author = author
#         self.avg_rating = avg_rating
#         self.format = book_format
#         self.image = image
#         self.num_pages = num_pages
#         self.pub_id = pub_id
#
#     def __repr__(self):
#         return '{} by {}'.format(self.title, self.author)
#
# The above code created 2 tables in the new database catalog_db and I verified it in the pgAdmin interface.

# %% [markdown]
# Publication table updated with the following data:
#
# INSERT INTO publication(id,name)
# VALUES
#
# (1, 'Oxford Publications'),
#
# (2, 'Paramount Press'),
#
# (3, 'Oracle Books Inc'),
#
# (4, 'Vintage Books and Comics'),
#
# (5, 'Trolls Press'),
#
# (6, 'Broadway Press'),
#
# (7, 'Downhill Publishers'),
#
# (8, 'Kingfisher Inc');

# %% [markdown]
# ![publisher_record.png](attachment:publisher_record.png)

# %% [markdown]
# Similarly the Books table is also updated.

# %% [markdown]
# ![books_record.png](attachment:books_record.png)

# %% [markdown]
# ## Using Bootstrap for Better Application User Interface (UI) Experience

# %% [markdown]
# - Created layout.html under catalog folder and styles.css under css within static.
# - Using Jinja2 templating command like {% extends 'layout.html' %} in the home.html
# - Updated publisher.html with {% extends 'layout.html' %}

# %% [markdown]
# Earlier I had missed installing Gunicorn, I added that as part of the virutal environment. **Green Unicorn**, commonly shortened to "Gunicorn", is a Web Server Gateway Interface (WSGI) server implementation that is commonly used to run Python web applications (Refer https://www.fullstackpython.com/green-unicorn-gunicorn.html to learn more about how we can use Gunicorn to run web applications based on python).
#
# With the use of pip freeze command in the pycharm terminal, now I can get the list of dependancies:
#
#     click==8.0.1
#     colorama==0.4.4
#     dominate==2.6.0
#     Flask==2.0.1
#     Flask-Bootstrap==3.3.7.1
#     Flask-SQLAlchemy==2.5.1
#     greenlet==1.1.0
#     gunicorn==20.1.0
#     importlib-metadata==4.6.3
#     itsdangerous==2.0.1
#     Jinja2==3.0.1
#     MarkupSafe==2.0.1
#     psycopg2==2.9.1
#     SQLAlchemy==1.4.22
#     typing-extensions==3.10.0.0
#     visitor==0.1.3
#     Werkzeug==2.0.1
#     zipp==3.5.0
#
# Based on the above, I created a requirements.txt file using the terminal with the below command:
#
# **pip freeze > requirements.txt**
#
# The above file gets created in the top level project folder.

# %% [markdown]
# ## Running of Books Catalog App from the Local Server in the Browser

# %% [markdown]
# In order to pull the database directly from the local PostgreSQL server, I am putting credentials in the 'dev' file as shown below (password changed to maintain the privacy):

# %% [markdown]
# ![dev.png](attachment:dev.png)

# %% [markdown]
# The main 'run.py' file is updated to run everything from the local server as shown below:

# %% [markdown]
# ![run_with_dev.png](attachment:run_with_dev.png)

# %% [markdown]
# Here is the snapshot of the books catalog application shown in the browser:

# %% [markdown]
# ![books_ui-2.png](attachment:books_ui-2.png)

# %% [markdown]
# Hyperlinks for the Publisher are working and if I click on any Publisher ID, it takes to the respective Publisher details as shown below for Publisher ID # 2 (Paramount Press).

# %% [markdown]
# ![publisher_ui.png](attachment:publisher_ui.png)

# %% [markdown]
# ## Video Walk-through of the Phase-1 Project

# %% [markdown]
# **Click at the below video image to watch walk-through video on YouTube**

# %% [markdown]
# [![phase1video_image.png](attachment:phase1video_image.png)](https://www.youtube.com/watch?v=f5x4QgHXQts)

# %% [markdown]
# **In case the above video does not upload due to any reason, please right-click here to open [Video Walkthrough for Phase-1 video](https://www.youtube.com/watch?v=f5x4QgHXQts) in a new window.**

# %% [markdown]
# # Phase-2: Deployment of Book Catalog Using GitHub, Amazon S3 & Heroku (To be done later)

# %% [markdown]
# ## Project Goals

# %% [markdown]
# *Phase-2: Deploy Book Catalog online using the following resources including creation of user login interface:*
#
# - **Use of Amazon S3 to store PostgreSQL database online for interaction with Heroku**
# - *Use of GitHub to store all the required files to interact with Heroku*
# - Focus on keeping the file structure fit for scalability of the web application
# - Use of **GitHub for continuous improvement and continuous delivery (CI/CD)** purpose so that app can be updated on as required basis in future

# %% [markdown]
# ## Project Execution Steps for Phase-2

# %% [markdown]
# ![bookcatalog_step4to6.jpg](attachment:bookcatalog_step4to6.jpg)

# %% [markdown]
# ### Deployment to Heroku via GitHub

# %% [markdown]
# - As per the Heroku requirements (Refer https://devcenter.heroku.com/articles/procfile), I created a Procfile.
#
# - I have also created a .gitignore file and added files which I don't want to be added to Heroku.
#
# - Log in to Heroku account or create the account (https://id.heroku.com/login) if there is no login credentials available.
#
# - Download Heroku CLI SO that it is easier to integrate everything via PyCharm terminal.
#
# - After creating the app with a unique name, create the postgreSQL database on Heroku

# %% [markdown]
# **Even though I have done some work for the second phase but a lot of work is required before this phase can be completed.**
